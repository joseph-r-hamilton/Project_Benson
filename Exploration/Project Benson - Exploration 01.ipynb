# %% [markdown]
# # Project Benson
#
# ## Exploring...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels
import seaborn as sns
from numpy import linalg

import math
import patsy

from statsmodels.formula.api import ols

# %matplotlib inline

# %%
# !python -V
# Out:
# Python 3.6.3 :: Anaconda custom (64-bit)

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 0.20.3
# Numpy version: 1.13.3

# %% [markdown]
# ### Pick a week and play...

# %%
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_170415.txt')

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/08/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/08/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/08/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/08/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/08/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6127245
# 1  REGULAR  6127285
# 2  REGULAR  6127304
# 3  REGULAR  6127409
# 4  REGULAR  6127654
#
#    EXITS
# 0                                            2076158
# 1                                            2076165
# 2                                            2076196
# 3                                            2076284
# 4                                            2076350

# %% [markdown]
# The field description from the source website:
#
# Field Description
#
# C/A,UNIT,SCP,STATION,LINENAME,DIVISION,DATE,TIME,DESC,ENTRIES,EXITS
#
#
# C/A      = Control Area (A002)
# UNIT     = Remote Unit for a station (R051)
# SCP      = Subunit Channel Position represents an specific address for a device (02-00-00)
# STATION  = Represents the station name the device is located at
# LINENAME = Represents all train lines that can be boarded at this station
#            Normally lines are represented by one character.  LINENAME 456NQR repersents train server for 4, 5, 6, N, Q, and R trains.
# DIVISION = Represents the Line originally the station belonged to BMT, IRT, or IND
# DATE     = Represents the date (MM-DD-YY)
# TIME     = Represents the time (hh:mm:ss) for a scheduled audit event
# DESc     = Represent the "REGULAR" scheduled audit event (Normally occurs every 4 hours)
#            1. Audits may occur more that 4 hours due to planning, or troubleshooting activities.
#            2. Additionally, there may be a "RECOVR AUD" entry: This refers to a missed audit that was recovered.
# ENTRIES  = The comulative entry register value for a device
# EXIST    = The cumulative exit register value for a device

# %% [markdown]
# So... things we need to do:
#
# * Strip out anything but "REGULAR" audits
# * Create derived columns
#   * Entry hits since last REGULAR audit
#   * Exit hits since last REGULAR audit
#   * Total of the two above
# * Determine how to aggregate the above per station
# * Incorporate geographical data per station

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201197 entries, 0 to 201196
# Data columns (total 11 columns):
# C/A                                                                     201197 non-null object
# UNIT                                                                    201197 non-null object
# SCP                                                                     201197 non-null object
# STATION                                                                 201197 non-null object
# LINENAME                                                                201197 non-null object
# DIVISION                                                                201197 non-null object
# DATE                                                                    201197 non-null object
# TIME                                                                    201197 non-null object
# DESC                                                                    201197 non-null object
# ENTRIES                                                                 201197 non-null int64
# EXITS                                                                   201197 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.9+ MB

# %% [markdown]
# Let's start small.
#
# It will be easier here to focus on just one device actually, even moreso than one station.
#
# So... what's going on with this data?  What's the real structure?  The field descriptions aren't quite so clear if you aren't familiar with the context...

# %%
df.apply(lambda x: x.value_counts().count())
# Out:
# C/A                                                                        732
# UNIT                                                                       466
# SCP                                                                        230
# STATION                                                                    374
# LINENAME                                                                   114
# DIVISION                                                                     6
# DATE                                                                         7
# TIME                                                                     12844
# DESC                                                                         2
# ENTRIES                                                                 168614
# EXITS                                                                   167922
# dtype: int64

# %% [markdown]
# Hmm... these are interesting counts.  The highest spread of the identifiers suggests "C/A" is truly the column of interest here - our key, so to speak.
#
# Found better guidance for the data:
# * [Turnstile Data Overview](https://data.ny.gov/api/views/ekwu-khcy/files/30554bf0-2ec6-4804-a91b-85185a96a877?download=true&filename=MTA_Turnstile_Data_Overview.pdf)
# * [Turnstile Data Dictionary](https://data.ny.gov/api/views/ekwu-khcy/files/e35d46bb-d988-44c5-a170-8736c1c773af?download=true&filename=MTA_Turnstile_Data_DataDictionary.pdf)

# %%
df.iloc[:,:2].drop_duplicates().count()
# Out:
# C/A     732
# UNIT    732
# dtype: int64

# %%
df.iloc[:,1:3].drop_duplicates().count()
# Out:
# UNIT    4691
# SCP     4691
# dtype: int64

# %%
df.loc[:,['UNIT','STATION']].drop_duplicates().count()
# Out:
# UNIT       482
# STATION    482
# dtype: int64

# %%
df.loc[:,['UNIT','STATION']].drop_duplicates().sort_values('STATION')
# Out:
#         UNIT          STATION
# 33027   R248             1 AV
# 162093  R180           103 ST
# 141872  R191           103 ST
# 48682   R314           103 ST
# 185617  R208    103 ST-CORONA
# 42146   R007           104 ST
# 68926   R354           104 ST
# 162357  R181           110 ST
# 42314   R008           111 ST
# 69131   R355           111 ST
# 185995  R310           111 ST
# 48094   R333           116 ST
# 167403  R324           116 ST
# 162612  R182           116 ST
# 142418  R159  116 ST-COLUMBIA
# 42486   R009           121 ST
# 47416   R102           125 ST
# 142670  R034           125 ST
# 167742  R206           125 ST
# 162944  R132           125 ST
# 168078  R207           135 ST
# 46954   R332           135 ST
# 142880  R169  137 ST CITY COL
# 163616  R307   138/GRAND CONC
# 99381   R163            14 ST
# 131431  R105            14 ST
# 57105   R175            14 ST
# 4535    R170   14 ST-UNION SQ
# 143300  R273           145 ST
# 168595  R344           145 ST
# ...      ...              ...
# 121821  R541  THIRTY THIRD ST
# 2600    R032   TIMES SQ-42 ST
# 135681  R033   TIMES SQ-42 ST
# 200479  R165    TOMPKINSVILLE
# 74825   R154       TREMONT AV
# 119825  R542  TWENTY THIRD ST
# 20537   R231         UNION ST
# 65945   R153         UTICA AV
# 146050  R117   V.CORTLANDT PK
# 40810   R434    VAN SICLEN AV
# 195945  R068    VAN SICLEN AV
# 67373   R441   VAN SICLEN AVE
# 178786  R276   VERNON-JACKSON
# 57534   R138   W 4 ST-WASH SQ
# 31725   R312  W 8 ST-AQUARIUM
# 173229  R145    WAKEFIELD/241
# 127647  R027          WALL ST
# 147444  R043          WALL ST
# 171000  R387    WEST FARMS SQ
# 177364  R107   WESTCHESTER SQ
# 9925    R001  WHITEHALL S-FRY
# 175297  R325      WHITLOCK AV
# 36521   R295        WILSON AV
# 196625  R451      WINTHROP ST
# 84636   R201   WOODHAVEN BLVD
# 41806   R006   WOODHAVEN BLVD
# 166941  R052         WOODLAWN
# 60554   R029  WORLD TRADE CTR
# 102712  R301          YORK ST
# 177112  R326        ZEREGA AV
#
# [482 rows x 2 columns]

# %% [markdown]
# Hmm... interesting.
#
# Let's take another tack here.  Let's assume most things are "REGULAR".  Or... that'd be easy to check...

# %%
df.loc[:,'DESC'].value_counts()
# Out:
# REGULAR       200444
# RECOVR AUD       753
# Name: DESC, dtype: int64

# %% [markdown]
# Yeah... I'd call that mostly.
#
# So, what are our widgets here?  Well, what are our timestamps?

# %%
print(len(df[df['DESC']=='REGULAR'].loc[:,['DATE','TIME']].drop_duplicates()))
df[df['DESC']=='REGULAR'].loc[:,['DATE','TIME']].drop_duplicates().head(10)
# Out:
# 13924
#          DATE      TIME
# 0  04/08/2017  00:00:00
# 1  04/08/2017  04:00:00
# 2  04/08/2017  08:00:00
# 3  04/08/2017  12:00:00
# 4  04/08/2017  16:00:00
# 5  04/08/2017  20:00:00
# 6  04/09/2017  00:00:00
# 7  04/09/2017  04:00:00
# 8  04/09/2017  08:00:00
# 9  04/09/2017  12:00:00

# %% [markdown]
# Nope.  Even "REGULAR" timestamps aren't perfect here.  But if we assume it's generally on a 4 hour pattern here.  This is one week, right?

# %%
df.loc[:,'DATE'].value_counts()
# Out:
# 04/12/2017    31452
# 04/13/2017    28679
# 04/14/2017    28380
# 04/10/2017    28373
# 04/11/2017    28211
# 04/08/2017    28088
# 04/09/2017    28014
# Name: DATE, dtype: int64

# %% [markdown]
# Yup.  And we can "see" it here.  We've got shy of 5000 things being recorded six times a day.

# %%
df.iloc[:,1:6].drop_duplicates().count()
# Out:
# UNIT        4691
# SCP         4691
# STATION     4691
# LINENAME    4691
# DIVISION    4691
# dtype: int64

# %%
df.iloc[:,1:3].drop_duplicates().count()
# Out:
# UNIT    4691
# SCP     4691
# dtype: int64

# %% [markdown]
# I cannot escape the feeling that some of these columns are keys and some are descriptive.  Well... in any case, let's move on...
#
# We can see even the "regular" timestamps aren't regular.  So we're going to need to do some work here.
# Let's practice with one widget.

# %%
widget_key = df.iloc[:,1:3].drop_duplicates().iloc[0,:]
widget_key
# Out:
# UNIT        R051
# SCP     02-00-00
# Name: 0, dtype: object

# %%
widget = df.query("UNIT=='R469' and SCP=='00-05-01'")
len(widget)
# Out:
# 42

# %% [markdown]
# Playing around I can see even the "REGULAR" timestamps that are "clean" don't all fall on the same four hour pattern.
#
# Yeah... we're simply going to have to resample...
#
# And for that, let's back up and parse the timestamp.

# %%
df2 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_170415.txt',
                       parse_dates = [['DATE','TIME']]
                      )

# %%
widget = df2.query("UNIT=='R051' and SCP=='02-00-00'").copy()
widget
# Out:
#              DATE_TIME   C/A  UNIT       SCP STATION LINENAME DIVISION  \
# 0  2017-04-08 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1  2017-04-08 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2  2017-04-08 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3  2017-04-08 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4  2017-04-08 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 5  2017-04-08 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 6  2017-04-09 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 7  2017-04-09 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 8  2017-04-09 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 9  2017-04-09 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 10 2017-04-09 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 11 2017-04-09 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 12 2017-04-10 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 13 2017-04-10 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 14 2017-04-10 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 15 2017-04-10 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 16 2017-04-10 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 17 2017-04-10 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 18 2017-04-11 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 19 2017-04-11 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 20 2017-04-11 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 21 2017-04-11 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 22 2017-04-11 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 23 2017-04-11 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 24 2017-04-12 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 25 2017-04-12 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 26 2017-04-12 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 27 2017-04-12 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 28 2017-04-12 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 29 2017-04-12 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 30 2017-04-13 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 31 2017-04-13 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 32 2017-04-13 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 33 2017-04-13 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 34 2017-04-13 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 35 2017-04-13 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 36 2017-04-14 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 37 2017-04-14 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 38 2017-04-14 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 39 2017-04-14 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 40 2017-04-14 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 41 2017-04-14 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#        DESC  ENTRIES  \
# 0   REGULAR  6127245
# 1   REGULAR  6127285
# 2   REGULAR  6127304
# 3   REGULAR  6127409
# 4   REGULAR  6127654
# 5   REGULAR  6128002
# 6   REGULAR  6128172
# 7   REGULAR  6128213
# 8   REGULAR  6128226
# 9   REGULAR  6128293
# 10  REGULAR  6128475
# 11  REGULAR  6128747
# 12  REGULAR  6128894
# 13  REGULAR  6128899
# 14  REGULAR  6128930
# 15  REGULAR  6129094
# 16  REGULAR  6129425
# 17  REGULAR  6130163
# 18  REGULAR  6130400
# 19  REGULAR  6130418
# 20  REGULAR  6130464
# 21  REGULAR  6130613
# 22  REGULAR  6130896
# 23  REGULAR  6131601
# 24  REGULAR  6131824
# 25  REGULAR  6131841
# 26  REGULAR  6131882
# 27  REGULAR  6132037
# 28  REGULAR  6132340
# 29  REGULAR  6133044
# 30  REGULAR  6133275
# 31  REGULAR  6133306
# 32  REGULAR  6133353
# 33  REGULAR  6133575
# 34  REGULAR  6133953
# 35  REGULAR  6134780
# 36  REGULAR  6135090
# 37  REGULAR  6135137
# 38  REGULAR  6135163
# 39  REGULAR  6135345
# 40  REGULAR  6135683
# 41  REGULAR  6136338
#
#     EXITS
# 0                                             2076158
# 1                                             2076165
# 2                                             2076196
# 3                                             2076284
# 4                                             2076350
# 5                                             2076398
# 6                                             2076417
# 7                                             2076419
# 8                                             2076440
# 9                                             2076512
# 10                                            2076556
# 11                                            2076614
# 12                                            2076644
# 13                                            2076647
# 14                                            2076742
# 15                                            2077006
# 16                                            2077079
# 17                                            2077140
# 18                                            2077160
# 19                                            2077163
# 20                                            2077257
# 21                                            2077478
# 22                                            2077564
# 23                                            2077620
# 24                                            2077642
# 25                                            2077647
# 26                                            2077742
# 27                                            2077948
# 28                                            2078018
# 29                                            2078066
# 30                                            2078098
# 31                                            2078104
# 32                                            2078207
# 33                                            2078434
# 34                                            2078496
# 35                                            2078558
# 36                                            2078583
# 37                                            2078585
# 38                                            2078660
# 39                                            2078822
# 40                                            2078871
# 41                                            2078921

# %%
widget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 10 columns):
# DATE_TIME                                                               42 non-null datetime64[ns]
# C/A                                                                     42 non-null object
# UNIT                                                                    42 non-null object
# SCP                                                                     42 non-null object
# STATION                                                                 42 non-null object
# LINENAME                                                                42 non-null object
# DIVISION                                                                42 non-null object
# DESC                                                                    42 non-null object
# ENTRIES                                                                 42 non-null int64
# EXITS                                                                   42 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 3.6+ KB

# %%
widget.reset_index()
widget2 = widget.set_index(pd.DatetimeIndex(widget['DATE_TIME'],inplace=True))

# %%
widget2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: